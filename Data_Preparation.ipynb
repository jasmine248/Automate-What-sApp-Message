# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmine248/Automate-What-sApp-Message/blob/main/Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
eu_loans = pd.read_csv('C:/Users/shaik/Downloads/titanic/train.csv', header = [1,2,3],skiprows=1,index_col=0,na_values=['_'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-29048f782c90> in <cell line: 1>()
# ----> 1 eu_loans = pd.read_csv('C:/Users/shaik/Downloads/titanic/train.csv', header = [1,2,3],skiprows=1,index_col=0,na_values=['_'])
#
# ...

# %%
import pandas as pd

# Adjust the path if the file is located elsewhere
file_path = 'C:\Users\shaik\Downloads\titanic\train.csv'

# Read the CSV file
eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])
print(eu_loans.head())
# Out:
#   File "<ipython-input-9-9579163f2b16>", line 4
#     file_path = 'C:\Users\shaik\Downloads\titanic\train.csv'
#                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# Use one of the following options to specify the file path correctly
file_path = 'C:\\Users\\shaik\\Downloads\\titanic\\train.csv'
# file_path = r'C:\Users\shaik\Downloads\titanic\train.csv'
# file_path = 'C:/Users/shaik/Downloads/titanic/train.csv'

# Read the CSV file
eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])
print(eu_loans.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-f7413a4d97ce> in <cell line: 9>()
#       7
#       8 # Read the CSV file
# ----> 9 eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])
#      10 print(eu_loans.head())
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53d9658e-3418-408d-a087-672e738370af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53d9658e-3418-408d-a087-672e738370af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_path = 'train.csv'  # Adjust the file path if needed
eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])
print(eu_loans.head())
# Out:
# 2  1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female    38  1  \
# 3  1  3                              Heikkinen, Miss. Laina  female    26  0
# 4  1  1        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35  1
# 5  0  3                           Allen, Mr. William Henry     male  35.0  0
# 6  0  3                                   Moran, Mr. James     male   NaN  0
# 7  0  1                            McCarthy, Mr. Timothy J     male  54.0  0
# 8  0  3                     Palsson, Master. Gosta Leonard     male   2.0  3
# 9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female  27.0  0
#
# 2  0         PC 17599  71.2833                 C85  C
# 3  0 STON/O2. 3101282    7.925 Unnamed: 10_level_1  S
# 4  0           113803     53.1                C123  S
# 5  0           373450   8.0500                 NaN  S
# 6  0           330877   8.4583                 NaN  Q
# 7  0            17463  51.8625                 E46  S
# ...

# %%
import pandas as pd

file_path = 'train.csv'  # Adjust the file path if needed
eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])
print(eu_loans.head())
# Out:
# 2  1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female    38  1  \
# 3  1  3                              Heikkinen, Miss. Laina  female    26  0
# 4  1  1        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35  1
# 5  0  3                           Allen, Mr. William Henry     male  35.0  0
# 6  0  3                                   Moran, Mr. James     male   NaN  0
# 7  0  1                            McCarthy, Mr. Timothy J     male  54.0  0
# 8  0  3                     Palsson, Master. Gosta Leonard     male   2.0  3
# 9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female  27.0  0
#
# 2  0         PC 17599  71.2833                 C85  C
# 3  0 STON/O2. 3101282    7.925 Unnamed: 10_level_1  S
# 4  0           113803     53.1                C123  S
# 5  0           373450   8.0500                 NaN  S
# 6  0           330877   8.4583                 NaN  Q
# 7  0            17463  51.8625                 E46  S
# ...

# %%
eu_loans.head()
# Out:
# 2  1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female    38  1  \
# 3  1  3                              Heikkinen, Miss. Laina  female    26  0
# 4  1  1        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35  1
# 5  0  3                           Allen, Mr. William Henry     male  35.0  0
# 6  0  3                                   Moran, Mr. James     male   NaN  0
# 7  0  1                            McCarthy, Mr. Timothy J     male  54.0  0
# 8  0  3                     Palsson, Master. Gosta Leonard     male   2.0  3
# 9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female  27.0  0
#
# 2  0         PC 17599  71.2833                 C85  C
# 3  0 STON/O2. 3101282    7.925 Unnamed: 10_level_1  S
# 4  0           113803     53.1                C123  S
# 5  0           373450   8.0500                 NaN  S
# 6  0           330877   8.4583                 NaN  Q
# 7  0            17463  51.8625                 E46  S
# ...

# %%
eu_loans.describe()
# Out:
# 2               1                      38           1           0     71.2833
# 3               1           3          26           0           0       7.925
# 4               1           1          35           1           0        53.1
# count  887.000000  887.000000  710.000000  887.000000  887.000000  887.000000
# mean     0.382187    2.310034   29.696014    0.521984    0.383315   32.192098
# std      0.486196    0.835000   14.559186    1.104741    0.807466   49.769476
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
eu_loans.cov().min()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ffa4c295788c> in <cell line: 1>()
# ----> 1 eu_loans.cov().min()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in cov(self, min_periods, ddof, numeric_only)
#   10208         cols = data.columns
#   10209         idx = cols.copy()
# > 10210         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10211
#   10212         if notna(mat).all():
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
import pandas as pd

# Load the dataset (ensure the file path is correct)
file_path = 'C:\\Users\\shaik\\Downloads\\titanic\\train.csv'
eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])

# Select only the numerical columns
numerical_data = eu_loans.select_dtypes(include=['float64', 'int64'])

# Calculate the covariance matrix
covariance_matrix = numerical_data.cov()

# Find the minimum value in the covariance matrix
min_covariance_value = covariance_matrix.min().min()
print("Minimum covariance value:", min_covariance_value)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-dd11f01ee494> in <cell line: 5>()
#       3 # Load the dataset (ensure the file path is correct)
#       4 file_path = 'C:\\Users\\shaik\\Downloads\\titanic\\train.csv'
# ----> 5 eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])
#       6
#       7 # Select only the numerical columns
#
# ...

# %%
import pandas as pd

# Assuming the file is uploaded to the current working directory
file_path = 'train.csv'  # Adjust the file path if necessary
eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])

# Select only the numerical columns
numerical_data = eu_loans.select_dtypes(include=['float64', 'int64'])

# Calculate the covariance matrix
covariance_matrix = numerical_data.cov()

min_covariance_value = covariance_matrix.min().min()
print("Minimum covariance value:", min_covariance_value)
# Out:
# Minimum covariance value: -22.806248389325603

# %%
import pandas as pd

# Check if the file exists
file_path = 'C:\\Users\\shaik\\Downloads\\titanic\\train.csv'
if os.path.exists(file_path):
    eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])

    # Select only the numerical columns
    numerical_data = eu_loans.select_dtypes(include=['float64', 'int64'])

    # Calculate the covariance matrix
    covariance_matrix = numerical_data.cov()

    # Find the minimum value in the covariance matrix
    min_covariance_value = covariance_matrix.min().min()
    print("Minimum covariance value:", min_covariance_value)
else:
    print(f"The file at {file_path} does not exist.")
# Out:
# The file at C:\Users\shaik\Downloads\titanic\train.csv does not exist.

# %%
eu_loans.corr
# Out:
# <bound method DataFrame.corr of 2    1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female    38  \
# 3    1  3                              Heikkinen, Miss. Laina  female    26
# 4    1  1        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 5    0  3                           Allen, Mr. William Henry     male  35.0
# 6    0  3                                   Moran, Mr. James     male   NaN
# 7    0  1                            McCarthy, Mr. Timothy J     male  54.0
# 8    0  3                     Palsson, Master. Gosta Leonard     male   2.0
# 9    1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female  27.0
# ..  .. ..                                                ...      ...   ...
# 887  0  2                              Montvila, Rev. Juozas     male  27.0
# 888  1  1                       Graham, Miss. Margaret Edith   female  19.0
# 889  0  3           Johnston, Miss. Catherine Helen "Carrie"   female   NaN
# ...

# %%
eu_loans.cov().min()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ffa4c295788c> in <cell line: 1>()
# ----> 1 eu_loans.cov().min()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in cov(self, min_periods, ddof, numeric_only)
#   10208         cols = data.columns
#   10209         idx = cols.copy()
# > 10210         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10211
#   10212         if notna(mat).all():
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
eu_loans.cov().min()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-ffa4c295788c> in <cell line: 1>()
# ----> 1 eu_loans.cov().min()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in cov(self, min_periods, ddof, numeric_only)
#   10208         cols = data.columns
#   10209         idx = cols.copy()
# > 10210         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10211
#   10212         if notna(mat).all():
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
import pandas as pd
import os

# Load the dataset (ensure the file path is correct)
file_path = 'C:\\Users\\shaik\\Downloads\\titanic\\train.csv'
if os.path.exists(file_path):
    eu_loans = pd.read_csv(file_path, header=[1, 2, 3], skiprows=1, index_col=0, na_values=['_'])

    # Print the data types to inspect which columns are numerical
    print(eu_loans.dtypes)

    # Select only the numerical columns
    numerical_data = eu_loans.select_dtypes(include=['float64', 'int64'])
    print(numerical_data.head())

    # Calculate the covariance matrix
    covariance_matrix = numerical_data.cov()
    print(covariance_matrix)

    # Find the minimum value in the covariance matrix
    min_covariance_value = covariance_matrix.min().min()
    print("Minimum covariance value:", min_covariance_value)
else:
    print(f"The file at {file_path} does not exist.")
# Out:
# The file at C:\Users\shaik\Downloads\titanic\train.csv does not exist.
